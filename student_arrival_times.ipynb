# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
attendance_df = pd.read_csv('data.csv', names = ('April 1st', 'April 2nd', 'April 3rd', 'April 4th', 'April 5th', 'April 8th'))
attendance_df.head(10)
# Out:
#   April 1st April 2nd April 3rd April 4th April 5th April 8th
# 0   8:56 AM   9:00 AM   7:45 AM   7:45 AM   8:05 AM   7:45 AM
# 1   8:40 AM   8:40 AM   8:30 AM   8:30 AM   8:45 AM   8:20 AM
# 2   8:45 AM   8:20 AM   8:05 AM   8:00 AM   8:05 AM   8:00 AM
# 3   8:40 AM   8:40 AM   8:40 AM   8:25 AM   8:40 AM   8:40 AM
# 4   8:55 AM   8:50 AM   8:55 AM   8:10 AM   8:15 AM   8:05 AM
# 5   8:45 AM   8:45 AM   8:45 AM   8:40 AM   8:30 AM   8:40 AM
# 6   8:45 AM   8:54 AM   8:38 AM   8:40 AM   8:32 AM   8:41 AM
# 7    absent  11:00 AM   8:35 AM   8:15 AM   8:10 AM   8:10 AM
# 8   8:39 AM   8:13 AM   8:15 AM   8:12 AM   8:10 AM   8:00 AM
# 9   9:00 AM   8:50 AM   8:50 AM   8:50 AM   8:40 AM   8:45 AM

# %%
attendance_df.loc[7,'April 1st'] = 'NULL'
attendance_df.head(10)
# Out:
#   April 1st April 2nd April 3rd April 4th April 5th April 8th
# 0   8:56 AM   9:00 AM   7:45 AM   7:45 AM   8:05 AM   7:45 AM
# 1   8:40 AM   8:40 AM   8:30 AM   8:30 AM   8:45 AM   8:20 AM
# 2   8:45 AM   8:20 AM   8:05 AM   8:00 AM   8:05 AM   8:00 AM
# 3   8:40 AM   8:40 AM   8:40 AM   8:25 AM   8:40 AM   8:40 AM
# 4   8:55 AM   8:50 AM   8:55 AM   8:10 AM   8:15 AM   8:05 AM
# 5   8:45 AM   8:45 AM   8:45 AM   8:40 AM   8:30 AM   8:40 AM
# 6   8:45 AM   8:54 AM   8:38 AM   8:40 AM   8:32 AM   8:41 AM
# 7      NULL  11:00 AM   8:35 AM   8:15 AM   8:10 AM   8:10 AM
# 8   8:39 AM   8:13 AM   8:15 AM   8:12 AM   8:10 AM   8:00 AM
# 9   9:00 AM   8:50 AM   8:50 AM   8:50 AM   8:40 AM   8:45 AM

# %%
april_1_times = list(attendance_df['April 1st'])
april_2_times = list(attendance_df['April 2nd'])
april_3_times = list(attendance_df['April 3rd'])
april_4_times = list(attendance_df['April 4th'])
april_5_times = list(attendance_df['April 5th'])
april_8_times = list(attendance_df['April 8th'])

all_times = []    
for i in april_1_times:
    all_times.append(i)
for i in april_2_times:
    all_times.append(i)
for i in april_3_times:
    all_times.append(i) 
for i in april_4_times:
    all_times.append(i)
for i in april_5_times:
    all_times.append(i)
for i in april_8_times:
    all_times.append(i)

times_series = pd.Series(all_times)   

times_no_null = []
for i in times_series:
    if i == 'NULL':
        None
    else:
        times_no_null.append(i)  

times_no_null        
times_no_nul
        
# 
# times_series_2 = pd.Series(times_no_null)
# time_counts = times_series_2.value_counts() 
# time_df = pd.DataFrame(time_counts)      
# time_df_index = time_df.reset_index()
#time_df_index
# Out:
# ['8:56 AM',
#  '8:40 AM',
#  '8:45 AM',
#  '8:40 AM',
#  '8:55 AM',
#  '8:45 AM',
#  '8:45 AM',
#  '8:39 AM',
#  '9:00 AM',
#  '8:40 AM',
#  '8:15 AM',
#  '8:45 AM',
#  '8:45 AM',
#  '8:45 AM',
#  '8:15 AM',
#  '8:45 AM',
#  '8:45 AM',
#  '8:50 AM',
#  '8:15 AM',
#  '8:45 AM',
#  '8:45 AM',
#  '8:45 AM',
#  '9:00 AM',
#  '8:40 AM',
#  '8:20 AM',
#  '8:40 AM',
#  '8:50 AM',
#  '8:45 AM',
#  '8:54 AM',
#  '11:00 AM',
#  '8:13 AM',
#  '8:50 AM',
#  '8:50 AM',
#  '8:30 AM',
#  '8:55 AM',
#  '8:45 AM',
#  '8:45 AM',
#  '8:40 AM',
#  '8:40 AM',
#  '9:00 AM',
#  '8:50 AM',
#  '9:00 AM',
#  '8:35 AM',
#  '8:45 AM',
#  '8:50 AM',
#  '7:45 AM',
#  '8:30 AM',
#  '8:05 AM',
#  '8:40 AM',
#  '8:55 AM',
#  '8:45 AM',
#  '8:38 AM',
#  '8:35 AM',
#  '8:15 AM',
#  '8:50 AM',
#  '8:40 AM',
#  '8:13 AM',
#  '8:45 AM',
#  '8:05 AM',
#  '9:00 AM',
#  '8:25 AM',
#  '8:45 AM',
#  '9:00 AM',
#  '8:57 AM',
#  '8:35 AM',
#  '8:27 AM',
#  '9:00 AM',
#  '8:30 AM',
#  '7:45 AM',
#  '8:30 AM',
#  '8:00 AM',
# ...

# %%
# time_no_null_newtime = (lambda x: pd.to_datetime(x).strftime('%H:%M:%S'))
# time_no_null_newtime.head()

# %%
plt.figure(figsize=[8,1.5])
plt.ylim(0,30)
plt.xlim(0,8)
plt.hist(times_no_null, bins = 30)
plt.xlabel('Time')
plt.ylabel('Student')
plt.title('Histograms in matplotlib')
plt.show()

# %%
# time_df_index['date'] = time_df_index['index'].apply(lambda x: pd.to_datetime(x).strftime('%H:%M:%S'))
# time_df_index.head()

# time_df_index['date'] = time_df_index['index'].map(lambda x: pd.Timestamp(x))
# time_df_index.head()

# %%
# time_df_drop_index = time_df_index.drop(['index'], axis = 1)
# time_df_drop_index.head()

# %%
#Zander's Code
# #I think I need to make a standard bar chart
# plt.figure(figsize=[8,1.5])
# plt.ylim(0,1.2)
# # plt.xlim(0,8)
# # plt.hist(x, bins=8)
# # plt.xlabel('Time')
# # plt.ylabel('Student')
# # plt.title('Histograms in matplotlib')
# # plt.show()


# objects = (time_df_drop_index['date'])
# y_pos = np.arange(len(objects))
# count = [time_df_drop_index['0']]
 
# plt.bar(y_pos, count, align='center', alpha=0.5)
# plt.xticks(y_pos, objects)
# plt.ylabel('Count')
# plt.title('Student Arrival Times')
 
# plt.show()
